# %% [markdown]
# <a href="https://colab.research.google.com/github/Gk1694/Association-Rule-Learning/blob/main/Color_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/cv.jpg')
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
image.shape
# Out:
# (1632, 3264, 3)

# %%
plt.figure(figsize=[12,8])
plt.imshow(image)
plt.title('Original image')
# Out:
# Text(0.5, 1.0, 'Original image')

# %%
blur = cv2.blur(image,(5,5))
blur0=cv2.medianBlur(blur,5)
blur1= cv2.GaussianBlur(blur0,(5,5),0)
blur2= cv2.bilateralFilter(blur1,9,75,75)

# %%
plt.imshow(blur2)

# %%
hsv = cv2.cvtColor(blur2, cv2.COLOR_BGR2HSV)

# %%
import numpy as np

# %%
low_blue = np.array([55, 0, 0])
high_blue = np.array([118, 255, 255])
mask = cv2.inRange(hsv, low_blue, high_blue)

# %%
plt.imshow(mask)

# %%
res = cv2.bitwise_and(img,img, mask= mask)

# %%
plt.imshow(res)
